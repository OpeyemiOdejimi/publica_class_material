# %% [markdown]
# ## AGENTIC RAG PROJECT

# %%
# from langchain_openai import ChatOpenAI
# from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
# from langgraph.graph import StateGraph, START, END, MessagesState
# from dotenv import load_dotenv
# load_dotenv()


from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_core.tools import tool
from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import ToolNode

# %%
# Load Documents

from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader


loader = DirectoryLoader(
    "documents/",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader
)


print("Starting PDF load...")
docs = loader.load()
print("Finished loading PDFs")
# Out:
# Starting PDF load...
# Finished loading PDFs

# %%
# Chunking strategy

# from langchain.text_splitter import RecursiveCharacterTextSplitter

# text_splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )

# chunks = text_splitter.split_documents(docs)


from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 225

# %%
# Embeddings and Chroma

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

embeddings = OpenAIEmbeddings()

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="./chroma_db"
)

# %%
# Let's test if it retrieves

vectorstore.similarity_search(
    "Subnets and IPv6 support",
    k=3
)
# Out:
# [Document(metadata={'page': 6, 'title': '01 Google Cloud VPC Networking Fundamentals 2.0.3_OD', 'creator': 'Google', 'source': 'documents\\01 Google Cloud VPC Networking Fundamentals 2.0_OD.pdf', 'total_pages': 48, 'creationdate': '', 'page_label': '7', 'producer': 'PyPDF'}, page_content='Subnets and IPv6 support●VPC networks now support IPv6 addresses.●Support for IPv6 addresses can vary per subnet.●To support IPv6, Google Cloud has introduced the concept of a subnet stack.○Single-stack subnets support IPv4.○Dual-stack subnets support IPv4 and IPv6.●IPv6 addresses can be assigned to objects in a subnet that supports IPv6.\nVPC networks now support IPv6 addresses.\nSupport for IPv6 addresses can vary per subnet. To support IPv6, Google Cloud has \nintroduced the concept of a subnet stack. The subnet stack defines the type of \naddress that can be assigned to objects in the subnet.\nSingle-stack subnets support IPv4. Dual-stack subnets support IPv4 and IPv6. \nThere’s no subnet that only supports IPv6.\nIPv6 addresses can be assigned to objects in a subnet that supports IPv6. In other \nwords, you can only assign IPv6 addresses to objects in a dual-stack subnet.'),
#  Document(metadata={'creationdate': '', 'title': '01 Google Cloud VPC Networking Fundamentals 2.0.3_OD', 'page_label': '11', 'total_pages': 48, 'page': 10, 'creator': 'Google', 'source': 'documents\\01 Google Cloud VPC Networking Fundamentals 2.0_OD.pdf', 'producer': 'PyPDF'}, page_content="IPv6 caveats\n02\nDual-stack subnets are not supported on auto mode VPC networks or legacy networks.01\nAny interface on a VM can have IPv6 addresses configured. \nWhen configuring your VPC networks and subnets to use IPv6 address, consider \nthese caveats:\nDual-stack subnets are not supported on auto mode VPC networks or legacy \nnetworks. If you have an auto mode VPC network that you want to add dual-stack \nsubnets to, you can convert the auto mode VPC network to custom mode.\nIf you're converting a legacy custom network, create new dual-stack subnets, or \nconvert existing subnets to dual-stack.\nAny interface on a VM can have IPv6 addresses configured."),
#  Document(metadata={'creationdate': '', 'producer': 'PyPDF', 'total_pages': 48, 'title': '01 Google Cloud VPC Networking Fundamentals 2.0.3_OD', 'creator': 'Google', 'page_label': '10', 'source': 'documents\\01 Google Cloud VPC Networking Fundamentals 2.0_OD.pdf', 'page': 9}, page_content="Assigning IPv6 address ranges to a subnet\n●When you enable IPv6 on a VM, the VM is assigned a /96 range from the subnet. ●The first IP address in that range is assigned to the primary interface.●You don't configure whether a VM gets internal or external IPv6 addresses. ○The VM inherits the IPv6 access type from the subnet.\nWhen you enable IPv6 on a VM, the VM is assigned a /96 range from the subnet that \nit's connected to. The first IP address in that range is assigned to the primary \ninterface.  You don't configure whether a VM gets internal or external IPv6 addresses. \nThe VM inherits the IPv6 access type from the subnet that it's connected to.")]

# %%
# Retrieval Tool

from langchain_core.tools import tool

@tool
def retrieve_docs(query: str) -> str:
    """
    Retrieve relevant documentation snippets for a query.
    """
    results = vectorstore.max_marginal_relevance_search(
        query,
        k=4,
        fetch_k=8
    )

    formatted = []
    for doc in results:
        formatted.append(
            f"Source: {doc.metadata.get('source')}\n{doc.page_content}"
        )

    return "\n\n---\n\n".join(formatted)

# %%
# LLM and tool binding (LangGraph)

tools = [retrieve_docs]

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
).bind_tools(tools)

# %%
# System Prompt
system_prompt = SystemMessage(
    content=(
        "You are studying Networking in Google Cloud . "
        "If a question requires specific documentation, use the retrieval tool. "
        "If the question is general knowledge, answer directly without retrieval."
    )
)

# %%
# Agent Node

def agent_node(state: MessagesState):
    messages = [system_prompt] + state["messages"]
    response = llm.invoke(messages)
    return {"messages": state["messages"] + [response]}

# %%
# Tool Node

from langgraph.prebuilt import ToolNode

tool_node = ToolNode(tools)

# %%
# Routing Logic

from typing import Literal

def route(state: MessagesState) -> Literal["tools", "__end__"]:
    last = state["messages"][-1]
    if getattr(last, "tool_calls", None):
        return "tools"
    return END

# %%
# Let's build LangGraph

graph = StateGraph(MessagesState)

graph.add_node("agent", agent_node)
graph.add_node("tools", tool_node)

graph.add_edge(START, "agent")

graph.add_conditional_edges(
    "agent",
    route,
    {
        "tools": "tools",
        END: END
    }
)

graph.add_edge("tools", "agent")

print(f'LangGraph created successfully')
# Out:
# LangGraph created successfully

# %%
# Let's compile with memory

memory = MemorySaver()
app = graph.compile(checkpointer=memory)

# %%
# Sanity Check

from langchain_core.messages import HumanMessage

# Example query that should trigger retrieval
query = "How do I set up a VPC in Google Cloud Networking?"

response = app.invoke(
    {"messages": [HumanMessage(content=query)]},
    config={"configurable": {"thread_id": "test"}}
)

# Display the agent's response
print(response["messages"][-1].content)
# Out:
# To set up a Virtual Private Cloud (VPC) in Google Cloud Networking, follow these general steps:
#
# 1. **Access Google Cloud Console**: Go to the Google Cloud Console and log in to your account.
#
# 2. **Create a VPC Network**:
#    - Navigate to the "VPC network" section in the console.
#    - Click on "Create VPC network."
#    - Provide a name for your VPC network.
#    - Choose the "Automatic" or "Custom" subnet creation option:
#      - **Automatic**: Google Cloud will create subnets in each region.
#      - **Custom**: You can define your own subnets.
#
# 3. **Configure Subnets** (if you chose Custom):
#    - Specify the name, region, and IP address range (CIDR block) for each subnet you want to create.
#
# 4. **Set Up Firewall Rules**:
#    - After creating the VPC, you may want to set up firewall rules to control traffic to and from your VPC network.
#    - Define rules based on your security requirements.
#
# 5. **Connect to Other Networks** (if needed):
#    - If you need to connect your VPC to on-premises networks, consider setting up a Cloud VPN or using Interconnect.
#
# 6. **Deploy Resources**:
#    - You can now deploy Compute Engine instances, Google Kubernetes Engine clusters, or other Google Cloud resources within your VPC.
#
# 7. **Review and Monitor**:
#    - Use the Google Cloud Console to monitor the performance and health of your VPC network.
#
# These steps will help you establish a VPC network that provides connectivity for your Google Cloud resources.

# %%
queries = [
    "What is VPC peering?",
    "Explain subnetting in Google Cloud Networking",
    "What is Network endpoint groups(NEG)",
    "What are IAM roles in Google Cloud?",
    "Briefly explain load balancing in Google Cloud"
]

for q in queries:
    response = app.invoke(
        {"messages": [HumanMessage(content=q)]},
        config={"configurable": {"thread_id": "test"}}
    )
    print(f"Query: {q}\nResponse: {response['messages'][-1].content}\n{'-'*50}")
# Out:
# Query: What is VPC peering?
# Response: VPC peering is a networking connection between two Virtual Private Cloud (VPC) networks that allows them to communicate with each other as if they were part of the same network. This connection enables resources in different VPCs to interact privately and securely without requiring public IP addresses or traversing the public internet. Here are the key aspects of VPC peering:
#
# 1. **Direct Communication**: VPC peering allows instances in one VPC to communicate with instances in another VPC using private IP addresses. This direct communication enhances security and reduces latency.
#
# 2. **No Transitive Peering**: VPC peering is non-transitive, meaning that if VPC A is peered with VPC B, and VPC B is peered with VPC C, instances in VPC A cannot communicate directly with instances in VPC C through VPC B. Each peering connection must be established individually.
#
# 3. **Same or Different Regions**: VPC peering can be established between VPCs in the same region or across different regions (inter-region peering), allowing for flexible network architectures.
#
# 4. **Resource Sharing**: VPC peering enables organizations to share resources across different VPCs, such as databases, applications, or services, without exposing them to the public internet.
#
# 5. **Security and Access Control**: VPC peering does not automatically grant access to resources. Network access control lists (ACLs) and firewall rules must be configured to allow traffic between the peered VPCs.
#
# 6. **Use Cases**:
#    - **Multi-Project Architecture**: Organizations can use VPC peering to connect VPCs across different projects, enabling resource sharing and collaboration.
#    - **Microservices Communication**: In a microservices architecture, different services can be deployed in separate VPCs and communicate securely through peering.
#    - **Hybrid Cloud Solutions**: VPC peering can facilitate communication between on-premises networks and cloud resources by connecting multiple VPCs.
#
# 7. **Cost**: While there are no additional charges for establishing a VPC peering connection, data transfer costs may apply for traffic flowing between the peered VPCs, depending on the cloud provider's pricing model.
#
# 8. **Limitations**: There are some limitations to VPC peering, such as the maximum number of active peering connections allowed per VPC and the need for careful management of IP address ranges to avoid conflicts.
#
# In summary, VPC peering is a powerful feature that enables secure and efficient communication between VPCs, making it a valuable tool for organizations looking to build scalable and interconnected cloud architectures.
# --------------------------------------------------
# Query: Explain subnetting in Google Cloud Networking
# Response: Subnetting in Google Cloud Networking involves dividing a Virtual Private Cloud (VPC) network into smaller, manageable segments called subnets. Each subnet can be used to organize resources, control traffic, and enhance security within the VPC. Here are the key aspects of subnetting in Google Cloud:
#
# 1. **CIDR Notation**: Subnets are defined using Classless Inter-Domain Routing (CIDR) notation, which specifies the IP address range for the subnet. For example, a subnet defined as `10.0.0.0/24` has an IP address range from `10.0.0.0` to `10.0.0.255`.
#
# 2. **Regional Subnets**: In Google Cloud, subnets are regional resources, meaning they exist within a specific region. Each subnet can span multiple zones within that region, allowing for high availability and redundancy.
#
# 3. **IP Address Allocation**: When you create a subnet, you must specify a range of IP addresses. Google Cloud automatically allocates IP addresses from this range to resources (like VM instances) that are created within the subnet.
#
# 4. **Custom and Automatic Subnets**:
#    - **Custom Subnets**: You define the IP ranges and create subnets according to your needs. This allows for more control over the network architecture.
#    - **Automatic Subnets**: Google Cloud can automatically create subnets in each region with predefined IP ranges when you create a VPC network.
#
# 5. **Firewall Rules**: Subnets can have associated firewall rules that control the traffic to and from the resources within the subnet. This allows you to enforce security policies at the subnet level.
#
# 6. **Routing**: Each subnet is associated with a routing table that determines how traffic is directed within the VPC and to external networks. Google Cloud automatically creates routes for subnets, but you can also define custom routes.
#
# 7. **Peering and Shared VPC**: Subnets can be shared across different projects using Shared VPC, allowing for centralized management of network resources while enabling different teams or projects to use the same network infrastructure.
#
# 8. **Best Practices**: When designing subnets, consider factors such as IP address utilization, future growth, and security requirements. It's often recommended to leave some IP address space for future expansion.
#
# By effectively using subnetting in Google Cloud, you can create a well-organized and secure network architecture that meets the needs of your applications and services.
# --------------------------------------------------
# Query: What is Network endpoint groups(NEG)
# Response: Network Endpoint Groups (NEGs) in Google Cloud are a way to manage and route traffic to specific endpoints, such as virtual machine (VM) instances, containers, or even external services. NEGs provide a flexible and efficient way to define how traffic is directed to your applications, especially in scenarios involving microservices or containerized applications. Here are the key features and characteristics of Network Endpoint Groups:
#
# 1. **Endpoint Management**: NEGs allow you to define a group of endpoints that can be used as backends for load balancers. Each endpoint can be a VM instance, a specific IP address, or a service running in a Google Kubernetes Engine (GKE) cluster.
#
# 2. **Types of NEGs**:
#    - **Zonal NEGs**: These are associated with a specific zone and can include VM instances or IP addresses within that zone.
#    - **Serverless NEGs**: These are used to route traffic to serverless applications, such as Cloud Run services or App Engine applications.
#    - **Internet NEGs**: These allow you to route traffic to external endpoints that are not hosted within Google Cloud.
#
# 3. **Load Balancing**: NEGs can be used as backends for various types of load balancers in Google Cloud, including HTTP(S) load balancers, TCP/UDP load balancers, and internal load balancers. This enables efficient traffic distribution across multiple endpoints.
#
# 4. **Health Checks**: Google Cloud can perform health checks on the endpoints defined in a NEG to ensure that traffic is only routed to healthy instances. If an endpoint fails a health check, it will be temporarily removed from the load balancer's backend pool.
#
# 5. **Dynamic Scaling**: NEGs support dynamic scaling of endpoints, allowing you to add or remove endpoints as needed without disrupting traffic flow. This is particularly useful in microservices architectures where services may scale up or down based on demand.
#
# 6. **Integration with Kubernetes**: NEGs can be used with Google Kubernetes Engine (GKE) to manage traffic to Kubernetes services. This allows for seamless integration between Kubernetes workloads and Google Cloud's load balancing capabilities.
#
# 7. **Granular Traffic Control**: By using NEGs, you can implement more granular traffic control and routing policies, allowing you to direct traffic based on specific criteria, such as URL paths or request headers.
#
# 8. **Use Cases**: NEGs are particularly useful in scenarios such as:
#    - Microservices architectures where different services need to be accessed independently.
#    - Load balancing traffic to containerized applications running in GKE.
#    - Routing traffic to serverless applications hosted on Cloud Run or App Engine.
#
# In summary, Network Endpoint Groups (NEGs) provide a flexible and efficient way to manage and route traffic to various endpoints in Google Cloud, enhancing the capabilities of load balancing and traffic management for modern applications.
# --------------------------------------------------
# Query: What are IAM roles in Google Cloud?
# Response: IAM (Identity and Access Management) roles in Google Cloud are a way to manage permissions for users, groups, and service accounts. They define what actions can be performed on specific resources within Google Cloud. Here are the key aspects of IAM roles:
#
# 1. **Role Types**:
#    - **Basic Roles**: These are predefined roles that provide broad access to Google Cloud resources. They include:
#      - **Owner**: Full control over all resources, including the ability to manage roles and permissions.
#      - **Editor**: Can modify all resources but cannot manage roles and permissions.
#      - **Viewer**: Read-only access to all resources.
#
#    - **Predefined Roles**: These roles are more granular and are designed for specific services. For example, a predefined role for Compute Engine might allow users to start and stop virtual machine instances without granting full access to all resources.
#
#    - **Custom Roles**: You can create custom roles that include specific permissions tailored to your organization's needs. This allows for fine-grained access control.
#
# 2. **Permissions**: Each role consists of a set of permissions that define what actions can be performed. For example, the permission `compute.instances.start` allows a user to start a virtual machine instance.
#
# 3. **Role Assignment**: Roles are assigned to users, groups, or service accounts at different levels, including:
#    - **Project Level**: Roles can be assigned to resources within a specific project.
#    - **Folder Level**: Roles can be assigned to all projects within a folder.
#    - **Organization Level**: Roles can be assigned to all resources within an organization.
#
# 4. **Principle of Least Privilege**: It's a best practice to assign the minimum necessary permissions to users and service accounts. This reduces the risk of unauthorized access and potential security breaches.
#
# 5. **IAM Policies**: IAM roles are part of IAM policies, which define who (identity) has what access (roles) to which resources (scope). Policies can be managed through the Google Cloud Console, gcloud command-line tool, or REST API.
#
# 6. **Audit Logging**: Google Cloud provides audit logs that track changes to IAM policies and role assignments, helping organizations monitor access and ensure compliance.
#
# By using IAM roles effectively, organizations can manage access to their Google Cloud resources securely and efficiently, ensuring that users have the appropriate permissions to perform their tasks while minimizing security risks.
# --------------------------------------------------
# Query: Briefly explain load balancing in Google Cloud
# Response: Load balancing in Google Cloud is a service that distributes incoming network traffic across multiple backend resources, such as virtual machine (VM) instances, containers, or serverless applications. This helps ensure high availability, reliability, and optimal performance of applications by preventing any single resource from becoming overwhelmed with traffic. Here are the key aspects of load balancing in Google Cloud:
#
# 1. **Types of Load Balancers**:
#    - **HTTP(S) Load Balancer**: Distributes HTTP and HTTPS traffic across multiple backend instances, providing features like SSL termination, URL-based routing, and global load balancing.
#    - **TCP/UDP Load Balancer**: Handles non-HTTP traffic, distributing TCP or UDP traffic across backend instances. It can be used for applications that require low-latency connections.
#    - **Internal Load Balancer**: Distributes traffic within a Virtual Private Cloud (VPC) network, allowing for load balancing of internal applications without exposing them to the public internet.
#    - **Network Load Balancer**: Provides a high-performance load balancing solution for TCP/UDP traffic at the network layer, suitable for applications requiring high throughput.
#
# 2. **Global and Regional Load Balancing**: Google Cloud offers both global and regional load balancing options. Global load balancers can distribute traffic across multiple regions, while regional load balancers operate within a specific region.
#
# 3. **Health Checks**: Load balancers perform health checks on backend instances to ensure that traffic is only routed to healthy instances. If an instance fails a health check, it is temporarily removed from the load balancer's backend pool.
#
# 4. **Autoscaling**: Load balancing can be integrated with autoscaling, allowing backend resources to automatically scale up or down based on traffic demand, ensuring optimal resource utilization.
#
# 5. **Session Affinity**: Load balancers can be configured to maintain session affinity, ensuring that requests from the same client are directed to the same backend instance, which is useful for stateful applications.
#
# 6. **Security Features**: Google Cloud load balancers provide built-in security features, such as SSL/TLS termination, DDoS protection, and integration with Google Cloud Armor for application security.
#
# In summary, load balancing in Google Cloud is a critical component for building scalable, reliable, and high-performance applications, enabling efficient distribution of traffic and enhancing user experience.
# --------------------------------------------------

# %%
queries = [
    "What is Python?",
    "Define cloud computing",
    "What is a VPN?",
    "Who invented TCP/IP?",
    "Explain what an API is"
]

for q in queries:
    response = app.invoke(
        {"messages": [HumanMessage(content=q)]},
        config={"configurable": {"thread_id": "test"}}
    )
    print(f"Query: {q}\nResponse: {response['messages'][-1].content}\n{'-'*50}")
# Out:
# Query: What is Python?
# Response: Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Here are some key features and characteristics of Python:
#
# 1. **Easy to Learn and Use**: Python's syntax is clear and straightforward, making it an excellent choice for beginners as well as experienced programmers.
#
# 2. **Interpreted Language**: Python code is executed line by line, which makes debugging easier and allows for interactive programming.
#
# 3. **Dynamically Typed**: In Python, you do not need to declare the type of a variable when you create it. The type is determined at runtime, which adds flexibility to the code.
#
# 4. **Extensive Standard Library**: Python comes with a rich standard library that provides modules and functions for various tasks, such as file I/O, system calls, web development, and data manipulation.
#
# 5. **Cross-Platform**: Python is available on various operating systems, including Windows, macOS, and Linux, allowing developers to write code that can run on different platforms without modification.
#
# 6. **Object-Oriented and Functional Programming**: Python supports multiple programming paradigms, including object-oriented programming (OOP) and functional programming, allowing developers to choose the best approach for their projects.
#
# 7. **Large Community and Ecosystem**: Python has a vast and active community, which contributes to a rich ecosystem of third-party libraries and frameworks. Popular libraries include NumPy and Pandas for data analysis, Flask and Django for web development, and TensorFlow and PyTorch for machine learning.
#
# 8. **Use Cases**: Python is widely used in various domains, including web development, data science, artificial intelligence, scientific computing, automation, and more.
#
# 9. **Open Source**: Python is an open-source language, meaning that its source code is freely available, and developers can contribute to its development.
#
# Overall, Python's versatility, ease of use, and strong community support make it one of the most popular programming languages in the world today.
# --------------------------------------------------
# Query: Define cloud computing
# Response: Cloud computing is a technology that allows users to access and store data and applications over the internet instead of on local servers or personal computers. It provides on-demand availability of computing resources, such as servers, storage, databases, networking, software, and analytics, without the need for direct active management by the user. Here are some key characteristics and components of cloud computing:
#
# 1. **On-Demand Self-Service**: Users can provision computing resources automatically as needed without requiring human interaction with service providers.
#
# 2. **Broad Network Access**: Cloud services are accessible over the internet from a variety of devices, including laptops, smartphones, and tablets.
#
# 3. **Resource Pooling**: Cloud providers use a multi-tenant model to serve multiple customers from the same physical resources, dynamically assigning and reallocating resources based on demand.
#
# 4. **Rapid Elasticity**: Cloud resources can be scaled up or down quickly to meet changing demands, allowing for flexibility and efficient resource utilization.
#
# 5. **Measured Service**: Cloud systems automatically control and optimize resource use by leveraging a metering capability at some level of abstraction appropriate to the type of service (e.g., storage, processing, bandwidth).
#
# ### Types of Cloud Computing Services:
#
# 1. **Infrastructure as a Service (IaaS)**: Provides virtualized computing resources over the internet. Users can rent virtual machines, storage, and networks. Examples include Amazon Web Services (AWS) EC2 and Google Cloud Compute Engine.
#
# 2. **Platform as a Service (PaaS)**: Offers a platform allowing customers to develop, run, and manage applications without dealing with the infrastructure. Examples include Google App Engine and Microsoft Azure App Service.
#
# 3. **Software as a Service (SaaS)**: Delivers software applications over the internet on a subscription basis. Users can access applications via a web browser without needing to install or maintain them. Examples include Google Workspace, Microsoft 365, and Salesforce.
#
# ### Deployment Models:
#
# 1. **Public Cloud**: Services are delivered over the public internet and shared across multiple organizations. Examples include AWS, Microsoft Azure, and Google Cloud Platform.
#
# 2. **Private Cloud**: Services are maintained on a private network and used exclusively by a single organization, providing greater control and security.
#
# 3. **Hybrid Cloud**: Combines public and private clouds, allowing data and applications to be shared between them. This model provides flexibility and more deployment options.
#
# 4. **Community Cloud**: Shared infrastructure for a specific community of users from organizations with common concerns (e.g., security, compliance).
#
# ### Benefits of Cloud Computing:
#
# - **Cost Efficiency**: Reduces the need for physical hardware and maintenance costs.
# - **Scalability**: Easily scale resources up or down based on demand.
# - **Accessibility**: Access services and data from anywhere with an internet connection.
# - **Disaster Recovery**: Provides backup and recovery solutions to protect data.
# - **Collaboration**: Facilitates collaboration among users in different locations.
#
# Overall, cloud computing has transformed the way organizations manage and utilize IT resources, enabling greater flexibility, efficiency, and innovation.
# --------------------------------------------------
# Query: What is a VPN?
# Response: A VPN, or Virtual Private Network, is a technology that creates a secure and encrypted connection over a less secure network, such as the internet. It allows users to send and receive data as if their devices were directly connected to a private network, providing privacy, security, and anonymity. Here are the key features and benefits of a VPN:
#
# 1. **Encryption**: VPNs encrypt the data transmitted between the user's device and the VPN server, making it difficult for third parties, such as hackers or government agencies, to intercept and read the data.
#
# 2. **Privacy and Anonymity**: By masking the user's IP address and routing internet traffic through the VPN server, a VPN helps protect the user's identity and location, enhancing online privacy.
#
# 3. **Secure Remote Access**: VPNs enable remote users to securely access a private network, such as a corporate network, from anywhere in the world. This is particularly useful for employees working from home or traveling.
#
# 4. **Bypassing Geo-Restrictions**: VPNs can help users access content that may be restricted or blocked in their geographic location, such as streaming services or websites. By connecting to a VPN server in a different country, users can appear to be browsing from that location.
#
# 5. **Protection on Public Wi-Fi**: Using a VPN on public Wi-Fi networks (e.g., in cafes or airports) helps protect sensitive data from potential eavesdropping by malicious actors on the same network.
#
# 6. **Types of VPNs**:
#    - **Remote Access VPN**: Allows individual users to connect to a private network from a remote location.
#    - **Site-to-Site VPN**: Connects entire networks to each other, allowing multiple users at different locations to communicate securely.
#    - **Client-to-Site VPN**: Similar to remote access, but typically used for connecting individual devices to a corporate network.
#
# 7. **Protocols**: VPNs use various protocols to establish secure connections, including:
#    - **OpenVPN**: An open-source protocol known for its strong security and flexibility.
#    - **IPsec**: A suite of protocols used to secure internet protocol (IP) communications.
#    - **L2TP (Layer 2 Tunneling Protocol)**: Often used in conjunction with IPsec for added security.
#    - **PPTP (Point-to-Point Tunneling Protocol)**: An older protocol that is less secure but easier to set up.
#
# 8. **Limitations**: While VPNs provide enhanced security and privacy, they are not a complete solution for online safety. Users should still practice good security hygiene, such as using strong passwords and being cautious about sharing personal information.
#
# In summary, a VPN is a valuable tool for enhancing online security, privacy, and access to restricted content, making it widely used by individuals and organizations alike.
# --------------------------------------------------
# Query: Who invented TCP/IP?
# Response: TCP/IP, which stands for Transmission Control Protocol/Internet Protocol, was developed by a team of researchers led by Vint Cerf and Bob Kahn in the 1970s. The development of TCP/IP was part of a project funded by the U.S. Department of Defense to create a robust, fault-tolerant networking protocol that could facilitate communication between different types of computer networks.
#
# The key milestones in the development of TCP/IP include:
#
# 1. **Initial Concepts**: The concepts for TCP/IP were outlined in a paper titled "A Protocol for Packet Network Intercommunication," published by Cerf and Kahn in 1974.
#
# 2. **Protocol Development**: The protocols were further refined and standardized in the following years, leading to the creation of the TCP and IP protocols as we know them today.
#
# 3. **Adoption**: TCP/IP was adopted as the standard networking protocol for the ARPANET (the precursor to the modern internet) in 1983, which marked a significant milestone in the history of networking.
#
# Vint Cerf and Bob Kahn are often referred to as the "fathers of the internet" for their pioneering work in developing TCP/IP and laying the foundation for the modern internet.
# --------------------------------------------------
# Query: Explain what an API is
# Response: An API, or Application Programming Interface, is a set of rules and protocols that allows different software applications to communicate with each other. It defines the methods and data formats that applications can use to request and exchange information, enabling developers to build software that can interact with other services, libraries, or platforms. Here are the key components and characteristics of APIs:
#
# 1. **Interface**: An API serves as an interface between different software systems, allowing them to interact without needing to understand the internal workings of each other.
#
# 2. **Endpoints**: APIs typically expose specific endpoints (URLs) that represent different functionalities or resources. Each endpoint corresponds to a specific operation that can be performed, such as retrieving data, updating records, or deleting resources.
#
# 3. **Request and Response**: Communication with an API usually involves sending a request to an endpoint and receiving a response. The request may include parameters, headers, and a body, while the response typically contains data in a structured format (e.g., JSON or XML).
#
# 4. **Methods**: APIs often use standard HTTP methods to define the type of operation being performed:
#    - **GET**: Retrieve data from the server.
#    - **POST**: Send data to the server to create a new resource.
#    - **PUT**: Update an existing resource on the server.
#    - **DELETE**: Remove a resource from the server.
#
# 5. **Authentication and Authorization**: Many APIs require authentication to ensure that only authorized users can access certain functionalities. This can be done using API keys, OAuth tokens, or other authentication methods.
#
# 6. **Types of APIs**:
#    - **Web APIs**: APIs that are accessed over the internet using HTTP/HTTPS protocols. They are commonly used for web services and applications.
#    - **Library APIs**: APIs provided by software libraries or frameworks that allow developers to use predefined functions and classes in their applications.
#    - **Operating System APIs**: APIs that allow applications to interact with the underlying operating system, such as file management or network communication.
#
# 7. **Use Cases**: APIs are widely used in various applications, including:
#    - Integrating third-party services (e.g., payment gateways, social media platforms).
#    - Accessing data from databases or external sources.
#    - Enabling communication between microservices in a distributed architecture.
#    - Building mobile applications that interact with backend services.
#
# 8. **Documentation**: Good API documentation is essential for developers to understand how to use the API effectively. It typically includes information about endpoints, request/response formats, authentication methods, and example usage.
#
# In summary, APIs play a crucial role in modern software development by enabling different systems to communicate and share data, fostering interoperability and innovation across applications and services.
# --------------------------------------------------

# %% [markdown]
# ## REPORT
#
#
# **Domain Selection**
#
# For this project, I chose Google Cloud Networking tutorials and study notes. This domain includes both general concepts, such as VPNs and subnets, and it is an integral part of the Associate Cloud Engineer Certificate Exam I am currently preparing for.
#
# **Chunk Size Tuning**
#
# The PDF documents were split into chunks using RecursiveCharacterTextSplitter, with a chunk size of 1000 characters and an overlap of 200. This setup ensures that each chunk contains enough context for meaningful embeddings, while overlapping content prevents information loss at chunk boundaries. After splitting, the collection resulted in 225 chunks, which balances retrieval efficiency with content completeness.
#
# **Retrieval Decisions**
#
# The agentic RAG system combines a Chroma vector store, OpenAI embeddings, and a retrieval tool decorated with @tool. Testing showed that domain-specific queries, like "Explain subnetting in Google Cloud," correctly triggered retrieval and returned relevant document chunks. General knowledge questions, such as "What is Python?" were answered directly without retrieval. Multi-turn conversations also worked correctly, as the MemorySaver preserved context, allowing coherent follow-ups.
#
# **System Performance**
#
# The system performed well: document loading, chunking, embedding, and vectorization were smooth; the agent made appropriate retrieval decisions; and memory successfully preserved context. Areas for improvement include optimizing retrieval relevance through alternative chunk sizes or reranking strategies, and improving speed by considering local embedding models to reduce dependency on OpenAI API calls.
#
# **Conclusion**
#
# Overall, the agentic RAG system effectively integrates documents, embeddings, retrieval, LLM, and memory to answer queries accurately. It demonstrates that a combination of LangGraph, LangChain, and a vector store can build a context-aware, intelligent agent suitable for technical domains.
